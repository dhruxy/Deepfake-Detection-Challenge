# %%
import numpy as np
import cv2
from skimage.io import imread
from skimage.transform import resize
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
train = np.zeros([800,256,256,3], dtype = np.float32)
labels_train = np.zeros(800)

# %%
def load_video(path, max_frames=1, resize=(256, 256)):
    cap = cv2.VideoCapture(path)
    i = 0
    frames = np.zeros([256,256,3], dtype = np.float32)
    try:
        while True:
            ret, frame = cap.read()
            if not ret:
                break
            frame = cv2.resize(frame, resize)
            frame = frame[:, :, [2, 1, 0]]
            frame = frame/255
            frames = frame
            i += 1
            if i == max_frames:
                break
    finally:
        cap.release()
    return np.array(frames)

def cut_save(main_dir,mod):
    i = 0
    for x in os.listdir(main_dir):
        print(x)
        td = main_dir+x+'/'
        for file in os.listdir(td):
            fl = os.path.join(td, file)
            print(fl)
            videos = load_video(fl)
            if mod == 'train':
                train[i] = (videos)
                
                if x =='real':
                    labels_train[i] = 1
                elif x == 'fake':
                    labels_train[i] = 0
                i +=1

# %%
DATA_DIR = '../Focus/Data/'
cut_save(DATA_DIR,"train")
# Out:
# fake
# ../Focus/Data/fake/00000.mp4
# ../Focus/Data/fake/00001.mp4
# ../Focus/Data/fake/000010.mp4
# ../Focus/Data/fake/0000100.mp4
# ../Focus/Data/fake/0000101.mp4
# ../Focus/Data/fake/0000102.mp4
# ../Focus/Data/fake/0000103.mp4
# ../Focus/Data/fake/0000104.mp4
# ../Focus/Data/fake/0000105.mp4
# ../Focus/Data/fake/0000106.mp4
# ../Focus/Data/fake/0000107.mp4
# ../Focus/Data/fake/0000108.mp4
# ../Focus/Data/fake/0000109.mp4
# ../Focus/Data/fake/000011.mp4
# ../Focus/Data/fake/0000110.mp4
# ../Focus/Data/fake/0000111.mp4
# ../Focus/Data/fake/0000112.mp4
# ../Focus/Data/fake/0000113.mp4
# ../Focus/Data/fake/0000114.mp4
# ../Focus/Data/fake/0000115.mp4
# ../Focus/Data/fake/0000116.mp4
# ../Focus/Data/fake/0000117.mp4
# ../Focus/Data/fake/0000118.mp4
# ../Focus/Data/fake/0000119.mp4
# ../Focus/Data/fake/000012.mp4
# ../Focus/Data/fake/0000120.mp4
# ../Focus/Data/fake/0000121.mp4
# ../Focus/Data/fake/0000122.mp4
# ../Focus/Data/fake/0000123.mp4
# ../Focus/Data/fake/0000124.mp4
# ../Focus/Data/fake/0000125.mp4
# ../Focus/Data/fake/0000126.mp4
# ../Focus/Data/fake/0000127.mp4
# ../Focus/Data/fake/0000128.mp4
# ../Focus/Data/fake/0000129.mp4
# ../Focus/Data/fake/000013.mp4
# ../Focus/Data/fake/0000130.mp4
# ../Focus/Data/fake/0000131.mp4
# ../Focus/Data/fake/0000132.mp4
# ../Focus/Data/fake/0000133.mp4
# ../Focus/Data/fake/0000134.mp4
# ../Focus/Data/fake/0000135.mp4
# ../Focus/Data/fake/0000136.mp4
# ../Focus/Data/fake/0000137.mp4
# ../Focus/Data/fake/0000138.mp4
# ../Focus/Data/fake/0000139.mp4
# ../Focus/Data/fake/000014.mp4
# ../Focus/Data/fake/0000140.mp4
# ../Focus/Data/fake/0000141.mp4
# ../Focus/Data/fake/0000142.mp4
# ../Focus/Data/real/67.mp4
# ../Focus/Data/real/69.mp4
# ../Focus/Data/real/7.mp4
# ../Focus/Data/real/70.mp4
# ../Focus/Data/real/71.mp4
# ../Focus/Data/real/72.mp4
# ../Focus/Data/real/73.mp4
# ../Focus/Data/real/74.mp4
# ../Focus/Data/real/75.mp4
# ../Focus/Data/real/76.mp4
# ../Focus/Data/real/77.mp4
# ../Focus/Data/real/78.mp4
# ../Focus/Data/real/79.mp4
# ../Focus/Data/real/80.mp4
# ../Focus/Data/real/81.mp4
# ../Focus/Data/real/82.mp4
# ../Focus/Data/real/83.mp4
# ../Focus/Data/real/84.mp4
# ../Focus/Data/real/85.mp4
# ../Focus/Data/real/86.mp4
# ../Focus/Data/real/87.mp4
# ../Focus/Data/real/88.mp4
# ../Focus/Data/real/89.mp4
# ../Focus/Data/real/9.mp4
# ../Focus/Data/real/90.mp4
# ../Focus/Data/real/91.mp4
# ../Focus/Data/real/92.mp4
# ../Focus/Data/real/93.mp4
# ../Focus/Data/real/94.mp4
# ../Focus/Data/real/95.mp4
# ../Focus/Data/real/96.mp4
# ../Focus/Data/real/97.mp4
# ../Focus/Data/real/98.mp4
# ../Focus/Data/real/99.mp4

# %%
print(labels_train[500])
# Out:
# 1.0

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(train,labels_train,test_size=0.2, random_state=42)

# %%
X_train.shape

# %%
plt.imshow(X_train[113])
plt.show()
print(y_train[112])

# %%
import tensorflow as tf
layers = tf.keras.layers
models = tf.keras.models
losses = tf.keras.losses
optimizers = tf.keras.optimizers 
metrics = tf.keras.metrics
utils = tf.keras.utils
callbacks = tf.keras.callbacks
layers = tf.keras.layers
models = tf.keras.models
ImageDataGenerator = tf.keras.preprocessing.image.ImageDataGenerator
losses = tf.keras.losses
optimizers = tf.keras.optimizers 
metrics = tf.keras.metrics
utils = tf.keras.utils
callbacks = tf.keras.callbacks
plot_model = tf.keras.utils.plot_model

# %%
np.random.seed(1234)
num_classes = 2

# %%
np.random.seed(1234)
num_classes = 2
vg19 = tf.keras.applications.vgg19.VGG19
base_model = vg19(include_top=False,weights='imagenet',input_shape=(224,224,3))
# Freeze the layers except the last 4 layers
for layer in base_model.layers:
    layer.trainable = False
# Check the trainable status of the individual layers
base_model.summary()

# %%
num_classes = 2

cnn = models.Sequential()
cnn.add(base_model)
cnn.add(layers.Flatten())
#cnn.add(layers.Dense(1024, activation='relu'))
#cnn.add(layers.Dropout(0.3))
#cnn.add(layers.Dense(512, activation='relu'))
#cnn.add(layers.Dropout(0.3))
#cnn.add(layers.LSTM(40))
# define LSTM model
model = models.Sequential()
model.add(layers.TimeDistributed(cnn,  input_shape=(30, 150, 150, 3)))
model.add(layers.LSTM(40 , return_sequences=True))
#model.add(layers.Dense(num_classes, activation="sigmoid"))
#model.add(layers.Dropout(0.3))
model.add(layers.TimeDistributed(layers.Dense(160, activation='relu')))
model.add(layers.GlobalAveragePooling1D(name="globale"))
'''
model.add(layers.Dense(1024, activation='relu'))
model.add(layers.Dropout(0.3))
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dropout(0.3))
'''
model.add(layers.Dense(num_classes, activation="sigmoid" , name="last"))
adam = optimizers.Adam(lr=0.0005, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
# model.load_weights('Deepfake.hdf5')
rms = optimizers.RMSprop()
model.compile(loss='binary_crossentropy', optimizer=adam, metrics=["accuracy"])
model.summary()

# %%
class AccuracyHistory(callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.acc = []
        self.val_acc = []
        self.loss = []
        self.val_loss = []

    def on_epoch_end(self, batch, logs={}):
        self.acc.append(logs.get('acc'))
        self.val_acc.append(logs.get('val_acc'))
        self.loss.append(logs.get('loss'))
        self.val_loss.append(logs.get('val_loss'))

history = AccuracyHistory()
earlyStopping = callbacks.EarlyStopping(monitor='val_loss', patience=8,min_delta=1e-5, verbose=0, mode='min')
mcp_save = callbacks.ModelCheckpoint('../Focus/weights/Video.hdf5', save_best_only=True, monitor='val_loss', mode='min')
reduce_lr_loss = callbacks.ReduceLROnPlateau(monitor='val_loss',patience=1, verbose=2,factor=0.5,min_lr=0.0000001)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-8f59a99b7e3b> in <module>
# ----> 1 class AccuracyHistory(meso.model.callbacks.Callback):
#       2     def on_train_begin(self, logs={}):
#       3         self.acc = []
#       4         self.val_acc = []
#       5         self.loss = []
#
# AttributeError: 'Functional' object has no attribute 'callbacks'

# %%
batch_size =3
epochs = 10

# %%
y_train = utils.to_categorical(y_train)
print(y_train)
y_test = utils.to_categorical(y_test)
print(y_test)

# %%
print(X_train)

# %%
model.fit(X_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1)

# %%
from tensorflow.keras.layers import Input, Dense, Flatten, Conv2D, MaxPooling2D, BatchNormalization, Dropout, Reshape, Concatenate, LeakyReLU
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model

# %%
class Classifier:
    def __init__():
        self.model = 0
    
    def predict(self, x):
        return self.model.predict(x)
    
    def fit(self, x, y):
        return self.model.train_on_batch(x, y)
    
    def get_accuracy(self, x, y):
        return self.model.test_on_batch(x, y)
    
    def load(self, path):
        self.model.load_weights(path)

# %%
# Create a MesoNet class using the Classifier

class Meso4(Classifier):
    def __init__(self, learning_rate = 0.001):
        self.model = self.init_model()
        optimizer = Adam(learning_rate = learning_rate)
        self.model.compile(optimizer = optimizer,
                           loss = 'mean_squared_error',
                           metrics = ['accuracy'])
    
    def init_model(self): 
        x = Input(shape = (256,256,3))
        
        x1 = Conv2D(8, (3, 3), padding='same', activation = 'relu')(x)
        x1 = BatchNormalization()(x1)
        x1 = MaxPooling2D(pool_size=(2, 2), padding='same')(x1)
        
        x2 = Conv2D(8, (5, 5), padding='same', activation = 'relu')(x1)
        x2 = BatchNormalization()(x2)
        x2 = MaxPooling2D(pool_size=(2, 2), padding='same')(x2)
        
        x3 = Conv2D(16, (5, 5), padding='same', activation = 'relu')(x2)
        x3 = BatchNormalization()(x3)
        x3 = MaxPooling2D(pool_size=(2, 2), padding='same')(x3)
        
        x4 = Conv2D(16, (5, 5), padding='same', activation = 'relu')(x3)
        x4 = BatchNormalization()(x4)
        x4 = MaxPooling2D(pool_size=(4, 4), padding='same')(x4)
        
        y = Flatten()(x4)
        y = Dropout(0.5)(y)
        y = Dense(16)(y)
        y = LeakyReLU(alpha=0.1)(y)
        y = Dropout(0.5)(y)
        y = Dense(1, activation = 'sigmoid')(y)

        return Model(inputs = x, outputs = y)

# %%
meso = Meso4()
meso.load('../Focus/weights/Meso4_DF.h5')
# Out:
# C:\Users\dhruv\Projects\Tensorflow object detection\TFODCourse\tfod\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
meso.model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 256, 256, 8)       224
# _________________________________________________________________
# batch_normalization (BatchNo (None, 256, 256, 8)       32
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 8)       1608
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128, 128, 8)       32
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 8)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 16)        3216
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64, 64, 16)        64
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 16)        6416
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32, 32, 16)        64
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 8, 8, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 16)                16400
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 16)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 28,073
# Trainable params: 27,977
# Non-trainable params: 96
# _________________________________________________________________

# %%
# Evaluating prediction
X = X_train
y = y_train
pred = meso.predict(X)
print(pred.shape)
count1 = 0
for i in range(640):
#     print(f"Predicted likelihood: {meso.predict(X)[0][0]:.4f}")
#     print(f"Actual label: {int(y[0])}")
    print(f"\nCorrect prediction: {round(pred[i][0])==y[i]}")
    if(round(pred[i][0])==y[i]):
        count1 += 1;
    
    
print(count1/640)
# Out:
# (640, 1)
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
# 0.628125

# %%
epochs = 100
batch_size = 16

# %%
meso.model.fit(X_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_split=0.2)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-35-03535af26626> in <module>
#       3           epochs=epochs,
#       4           verbose=1,
# ----> 5           validation_split=0.2)
#
# ~\Projects\Tensorflow object detection\TFODCourse\tfod\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1146           use_multiprocessing=use_multiprocessing,
#    1147           model=self,
# -> 1148           steps_per_execution=self._steps_per_execution)
#    1149
#    1150       # Container that configures and calls `tf.keras.Callback`s.
#
# ~\Projects\Tensorflow object detection\TFODCourse\tfod\lib\site-packages\keras\engine\data_adapter.py in get_data_handler(*args, **kwargs)
#    1381   if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1382     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1383   return DataHandler(*args, **kwargs)
#    1384
#    1385
#
# ~\Projects\Tensorflow object detection\TFODCourse\tfod\lib\site-packages\keras\engine\data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1148         use_multiprocessing=use_multiprocessing,
#    1149         distribution_strategy=tf.distribute.get_strategy(),
# -> 1150         model=model)
#    1151
#    1152     strategy = tf.distribute.get_strategy()
#
# ~\Projects\Tensorflow object detection\TFODCourse\tfod\lib\site-packages\keras\engine\data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     228                **kwargs):
#     229     super(TensorLikeDataAdapter, self).__init__(x, y, **kwargs)
# --> 230     x, y, sample_weights = _process_tensorlike((x, y, sample_weights))
#     231     sample_weight_modes = broadcast_sample_weight_modes(
#     232         sample_weights, sample_weight_modes)
#
# ~\Projects\Tensorflow object detection\TFODCourse\tfod\lib\site-packages\keras\engine\data_adapter.py in _process_tensorlike(inputs)
#    1029     return x
#    1030
# -> 1031   inputs = tf.nest.map_structure(_convert_numpy_and_scipy, inputs)
#    1032   return tf.__internal__.nest.list_to_tuple(inputs)
#    1033
#
# ~\Projects\Tensorflow object detection\TFODCourse\tfod\lib\site-packages\tensorflow\python\util\nest.py in map_structure(func, *structure, **kwargs)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# ~\Projects\Tensorflow object detection\TFODCourse\tfod\lib\site-packages\tensorflow\python\util\nest.py in <listcomp>(.0)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# ~\Projects\Tensorflow object detection\TFODCourse\tfod\lib\site-packages\keras\engine\data_adapter.py in _convert_numpy_and_scipy(x)
#    1024       if issubclass(x.dtype.type, np.floating):
#    1025         dtype = backend.floatx()
# -> 1026       return tf.convert_to_tensor(x, dtype=dtype)
#    1027     elif _is_scipy_sparse(x):
#    1028       return _scipy_sparse_to_sparse_tensor(x)
#
# ~\Projects\Tensorflow object detection\TFODCourse\tfod\lib\site-packages\tensorflow\python\util\dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~\Projects\Tensorflow object detection\TFODCourse\tfod\lib\site-packages\tensorflow\python\framework\ops.py in convert_to_tensor_v2_with_dispatch(value, dtype, dtype_hint, name)
#    1429   """
#    1430   return convert_to_tensor_v2(
# -> 1431       value, dtype=dtype, dtype_hint=dtype_hint, name=name)
#    1432
#    1433
#
# ~\Projects\Tensorflow object detection\TFODCourse\tfod\lib\site-packages\tensorflow\python\framework\ops.py in convert_to_tensor_v2(value, dtype, dtype_hint, name)
#    1439       name=name,
#    1440       preferred_dtype=dtype_hint,
# -> 1441       as_ref=False)
#    1442
#    1443
#
# ~\Projects\Tensorflow object detection\TFODCourse\tfod\lib\site-packages\tensorflow\python\profiler\trace.py in wrapped(*args, **kwargs)
#     161         with Trace(trace_name, **trace_kwargs):
#     162           return func(*args, **kwargs)
# --> 163       return func(*args, **kwargs)
#     164
#     165     return wrapped
#
# ~\Projects\Tensorflow object detection\TFODCourse\tfod\lib\site-packages\tensorflow\python\framework\ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1564
#    1565     if ret is None:
# -> 1566       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1567
#    1568     if ret is NotImplemented:
#
# ~\Projects\Tensorflow object detection\TFODCourse\tfod\lib\site-packages\tensorflow\python\framework\tensor_conversion_registry.py in _default_conversion_function(***failed resolving arguments***)
#      50 def _default_conversion_function(value, dtype, name, as_ref):
#      51   del as_ref  # Unused.
# ---> 52   return constant_op.constant(value, dtype, name=name)
#      53
#      54
#
# ~\Projects\Tensorflow object detection\TFODCourse\tfod\lib\site-packages\tensorflow\python\framework\constant_op.py in constant(value, dtype, shape, name)
#     270   """
#     271   return _constant_impl(value, dtype, shape, name, verify_shape=False,
# --> 272                         allow_broadcast=True)
#     273
#     274
#
# ~\Projects\Tensorflow object detection\TFODCourse\tfod\lib\site-packages\tensorflow\python\framework\constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     281       with trace.Trace("tf.constant"):
#     282         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 283     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     284
#     285   g = ops.get_default_graph()
#
# ~\Projects\Tensorflow object detection\TFODCourse\tfod\lib\site-packages\tensorflow\python\framework\constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     306 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     307   """Creates a constant on the current device."""
# --> 308   t = convert_to_eager_tensor(value, ctx, dtype)
#     309   if shape is None:
#     310     return t
#
# ~\Projects\Tensorflow object detection\TFODCourse\tfod\lib\site-packages\tensorflow\python\framework\constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     104       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     105   ctx.ensure_initialized()
# --> 106   return ops.EagerTensor(value, ctx.device_name, dtype)
#     107
#     108
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run _EagerConst: Dst tensor is not initialized.

# %%
X = X_test
y = y_test
pred = meso.predict(X)
count1 = 0
for i in range(160):
#     print(f"Predicted likelihood: {meso.predict(X)[0][0]:.4f}")
#     print(f"Actual label: {int(y[0])}")
    print(f"\nCorrect prediction: {round(pred[i][0])==y[i]}")
    if(round(pred[i][0])==y[i]):
        count1 += 1;
    
    
print(count1/160)
# Out:
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: False
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
#
# Correct prediction: True
# 0.9
